# %% [markdown]
# #### IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### IMPORT RAW DATA

# %%
df=pd.read_csv("C:/Users/lekhs/OneDrive/Documents/titanic ds/train.csv")

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# #### MISSING VALUES

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# #### REMOVE DUPLICATES

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### DESCRIBE VALUES

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #### INFO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                 Sex     Age   SibSp  Parch  Ticket    Fare     Cabin        Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0  1      0      PC 17599  71.2833  C85          C           1
# 4            1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)         female  35.0  1      0      113803    53.1000  C123         S           1
# 7            0         1       McCarthy, Mr. Timothy J                              male    54.0  0      0      17463     51.8625  E46          S           1
# 11           1         3       Sandstrom, Miss. Marguerite Rut                      female  4.0   1      1      PP 9549   16.7000  G6           S           1
# 12           1         1       Bonnell, Miss. Elizabeth                             female  58.0  0      0      113783    26.5500  C103         S           1
# ...

# %% [markdown]
# #### PAIRPLOT THROUGH SEABORN

# %%
sns.pairplot(df, diag_kind='kde',
             kind='reg')

# %% [raw]
# It shows the different kinds of pairplot with different variables. It measures the data points with each other for occurance.data points are vary with others, it defines the week relation.

# %%
sns.pairplot(df, hue='Sex')

# %% [raw]
# It finds the pattern between male and female wheather, correlation in age, fare, survived and more on. More strong relation in age So, survived also has strong relation and same pattern.Male has high in age and Pclass.

# %%
sns.pairplot(df, hue='Sex',
             kind="scatter",
             diag_kind="kde",
             palette={"male":"blue","female":"pink"},
             height=4,
             corner=True)

# %%
sns.pairplot(df)

# %% [markdown]
# #### HEATMAP THROUGH SEABORN

# %%
df=pd.read_csv("C:/Users/lekhs/OneDrive/Documents/titanic ds/gender_submission.csv")

# %%
sns.heatmap(df)
plt.show()

# %% [raw]
# This identify the pattern, correlation and also if there is any missing value. Below 170 ID were survived, between 350 to 720 were caused some injury and some may died after finding them.

# %%
sns.heatmap(corr,
            annot=False,       
            fmt=".1f",        
            cmap='YlGnBu',    
            linewidths=1.5,   
            linecolor='black',
            cbar=True)  
plt.title("Correlation Heatmap", fontsize=14)
plt.show()

# %% [raw]
# This shows more ID has died before finding, the values represent amount of lives.

# %% [markdown]
# #### VISUALIZATION BY SCATTER PLOT

# %%
df=pd.read_csv("C:/Users/lekhs/OneDrive/Documents/titanic ds/train.csv")

# %%
df.plot(kind='scatter', x="PassengerId", y="Age", color="black")
plt.title("Passenger age")
plt.ylabel("Age")
plt.xlabel("PassengerId")
plt.show()

# %% [raw]
# Scatter plot finds the relationship are strong betwwen 20 and 40. It has linear in form so, it can describe the all the ages are present in the titantic.Whereas, it has positive correlation.Week data points around the age of 50+.

# %%
df.plot(kind='scatter', x="PassengerId", y="Fare", color="grey")
plt.title("ALIVE")
plt.ylabel("Fare")
plt.xlabel("PassengerId")
plt.show()

# %% [raw]
# It has more strong relationship with fare because, every ID has paid their amount before the journey excluding some ID. This was done in short period of time.

# %% [markdown]
# #### VISUALIZATION BY BOX PLOT

# %%
sns.boxplot(x="Sex", y="Pclass", data=df)
plt.show()

# %% [raw]
# By applying boxplot, the comparing and analyzing the two different values gains the pattern and identification for the results. This finds from the median, outliers of the data. Female has smallest data points and median has 2, above 2 common to each other.

# %% [markdown]
# #### VISUALIZATION BY HISTOGRAMS

# %%
df["Pclass"].hist(bins=25,figsize=(6,6), xrot=25, grid=True)
plt.xlabel("Pclass"),
plt.ylabel("ID"),
plt.show()

# %% [raw]
# From this analysis,there are more than 400 ID are Pclass and whereas the other ID are supplimentary at the fare to identification.
